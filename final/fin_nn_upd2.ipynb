# %% [markdown]
# Примечание: это вторая часть задания.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
qrr = pd.read_csv('macro_quarterly.csv')
qrr_index = pd.to_datetime(qrr["date"], format="%d/%m/%Y")
qrr = qrr.drop(["date"], axis="columns")
qrr.index = qrr_index
qrr = qrr.asfreq("MS").interpolate(method='polynomial', order=7)
plt.plot(qrr["netexp"])
len(qrr["gdp"])
# Out:
# 478

# %%
mth = pd.read_csv('macro_monthly.csv')
df_index = pd.to_datetime(mth["DATE"], format="%Y-%m-%d")
mth = mth.drop(["DATE"], axis="columns")
mth.index = df_index
df = mth.copy(deep=True)
for c in qrr.columns:
    df[c] = qrr[c].copy(deep=True)
#df["reer"] = df["reer"].fillna(df["reer"].mean())
#df["tcs"] = df["tcs"].fillna(df["tcs"].mean())
df = df.dropna().asfreq('W').interpolate(method='polynomial', order=1).dropna()

# %%
fig, axes = plt.subplots(nrows=7, ncols=2, dpi=120, figsize=(10,25))
for i, ax in enumerate(axes.flatten()):
    data = df[df.columns[i]]
    ax.plot(data, color='red', linewidth=1)
    # Decorations
    ax.set_title(df.columns[i])
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)

plt.show()

# %%
train = df[:int(0.9*(len(data)))]
test = df[int(0.9*(len(data))):]

# %%
import numpy as np
from sklearn.metrics import (mean_absolute_error, mean_squared_error,
                            r2_score)
from math import sqrt

def mean_absolute_percentage_error(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def validate(true, pred):
    print("MSE:", mean_squared_error(true, pred))
    print("RMSE:", sqrt(mean_squared_error(true, pred)))
    print("MAE:", mean_absolute_error(true, pred))
    print("MAPE:", mean_absolute_percentage_error(true, pred))
    print("R2:", r2_score(true, pred))

# %% [markdown]
# ### Нейронные сети

# %% [markdown]
# ##### RNN

# %%
# !pip install scikeras
# Out:
# Requirement already satisfied: scikeras in c:\users\иван\appdata\local\programs\python\python311\lib\site-packages (0.12.0)
# Requirement already satisfied: packaging>=0.21 in c:\users\иван\appdata\roaming\python\python311\site-packages (from scikeras) (23.1)
# Requirement already satisfied: scikit-learn>=1.0.0 in c:\users\иван\appdata\local\programs\python\python311\lib\site-packages (from scikeras) (1.3.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem<0.32,>=0.23.1 in c:\users\иван\appdata\local\programs\python\python311\lib\site-packages (from scikeras) (0.31.0)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in c:\users\иван\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn>=1.0.0->scikeras) (1.26.0)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\иван\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn>=1.0.0->scikeras) (1.11.2)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\иван\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn>=1.0.0->scikeras) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\иван\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn>=1.0.0->scikeras) (3.2.0)

# %%
import torch
from torch import nn
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, LSTM, GRU
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from scikeras.wrappers import KerasRegressor
from sklearn.model_selection import GridSearchCV
# Out:
# WARNING:tensorflow:From c:\Users\Иван\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
def createXY(dataset,n_past):
    #dataset = ds.values
    dataX = []
    dataY = []
    for i in range(n_past, len(dataset)):
            dataX.append(dataset[i - n_past:i, 0:dataset.shape[1]])
            dataY.append(dataset[i,:])
    return np.array(dataX),np.array(dataY)

# %%
import numpy as np
from sklearn.metrics import (mean_absolute_error, mean_squared_error,
                            r2_score)
from math import sqrt

def mean_absolute_percentage_error(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def validate(true, pred):
    print("MSE:", mean_squared_error(true, pred))
    print("RMSE:", sqrt(mean_squared_error(true, pred)))
    print("MAE:", mean_absolute_error(true, pred))
    print("MAPE:", mean_absolute_percentage_error(true, pred))
    print("R2:", r2_score(true, pred))

# %%
from sklearn.metrics import mean_absolute_error
import copy
def build_model(npas, hout, p):
    icol = 14
    grid_model = Sequential()
    grid_model.add(SimpleRNN(hout, input_shape=(npas,icol), activation='relu'))
    grid_model.add(Dropout(p))
    grid_model.add(Dense(icol))

    grid_model.compile(loss = 'mse', optimizer = Adam(learning_rate=1e-3))
    return grid_model


min_error = None
best_params = {'npas': 1, 'hout': 2, 'p': 3}
for p in [0.05]:
    for hout in [1000, 2500]:
        for n_past in range(1, 11):
            params = {'npas': n_past*12, 'hout': hout, 'p': p}
            print("; ".join([key + ': ' + str(params[key]) for key in params.keys()]))
            npas = n_past * 12
            trainX,trainY=createXY(train,npas)
            testX,testY=createXY(pd.concat([train.iloc[-npas:,:], test]),npas)
            #grid_model = KerasRegressor(model=build_model(npas, hout, p),verbose=1, fit__validation_data=(testX,testY))
            grid_model = build_model(npas, hout, p)
            '''grid_search  = GridSearchCV(estimator = grid_model,
                                param_grid = {'epochs': [15]},
                                cv = 2,
                                verbose=True)'''

            blindshot=grid_model.predict(testX)
            print("MAE without education:" + str(mean_absolute_error(blindshot, testY)))
            grid_fit = grid_model.fit(trainX,trainY,epochs=128,batch_size=512,verbose=0)
            prediction=grid_model.predict(testX)
            print("MAE with education:" + str(mean_absolute_error(prediction, testY)))
            print()
            if min_error is None or mean_absolute_error(prediction, testY) < min_error:
                best_params = {'npas': npas, 'hout': hout, 'p': p}
                min_error = mean_absolute_error(prediction, testY)
                best = copy.deepcopy(prediction)
                best_test = copy.deepcopy(testY)
# Out:
# npas: 12; hout: 1000; p: 0.05
# 2/2 [==============================] - 0s 13ms/step
# MAE without education:159914.8915149821
# 2/2 [==============================] - 0s 10ms/step
# MAE with education:2895.9995841754317
#
# npas: 24; hout: 1000; p: 0.05
# 2/2 [==============================] - 0s 12ms/step
# MAE without education:162120.03409374738
# 2/2 [==============================] - 0s 12ms/step
# MAE with education:3565.4662901269553
#
# npas: 36; hout: 1000; p: 0.05
# 2/2 [==============================] - 0s 15ms/step
# MAE without education:178826.32706993917
# 2/2 [==============================] - 0s 16ms/step
# MAE with education:3387.0452441573107
#
# npas: 48; hout: 1000; p: 0.05
# 2/2 [==============================] - 0s 20ms/step
# MAE without education:146582.1267375259
# 2/2 [==============================] - 0s 19ms/step
# MAE with education:3466.251006144444
#
# npas: 60; hout: 1000; p: 0.05
# 2/2 [==============================] - 0s 24ms/step
# MAE without education:154778.74625274073
# 2/2 [==============================] - 0s 24ms/step
# MAE with education:2972.722761502056
#
# npas: 72; hout: 1000; p: 0.05
# 2/2 [==============================] - 0s 25ms/step
# MAE without education:152373.3167867832
# 2/2 [==============================] - 0s 25ms/step
# MAE with education:3817.5653460742137
#
# npas: 84; hout: 1000; p: 0.05
# 2/2 [==============================] - 0s 30ms/step
# MAE without education:175478.7682657978
# 2/2 [==============================] - 0s 30ms/step
# MAE with education:3110.029036166813
#
# npas: 96; hout: 1000; p: 0.05
# 2/2 [==============================] - 0s 32ms/step
# MAE without education:147478.636284005
# 2/2 [==============================] - 0s 33ms/step
# MAE with education:3621.9858507111308
#
# npas: 108; hout: 1000; p: 0.05
# 2/2 [==============================] - 0s 35ms/step
# MAE without education:184025.47696124087
# 2/2 [==============================] - 0s 55ms/step
# MAE with education:4403.560496898081
#
# npas: 120; hout: 1000; p: 0.05
# 2/2 [==============================] - 1s 61ms/step
# MAE without education:144511.08890634036
# 2/2 [==============================] - 0s 39ms/step
# MAE with education:3592.4814762701644
#
# npas: 12; hout: 2500; p: 0.05
# 2/2 [==============================] - 0s 33ms/step
# MAE without education:137529.7738073065
# 2/2 [==============================] - 0s 33ms/step
# MAE with education:3786.3715259587652
#
# npas: 24; hout: 2500; p: 0.05
# 2/2 [==============================] - 1s 73ms/step
# MAE without education:123083.06076710354
# 2/2 [==============================] - 0s 55ms/step
# MAE with education:3802.36297624099
#
# npas: 36; hout: 2500; p: 0.05
# 2/2 [==============================] - 1s 76ms/step
# MAE without education:153167.84355000718
# 2/2 [==============================] - 0s 79ms/step
# MAE with education:3742.3411450875174
#
# npas: 48; hout: 2500; p: 0.05
# 2/2 [==============================] - 1s 130ms/step
# MAE without education:130810.40968457828
# 2/2 [==============================] - 1s 122ms/step
# MAE with education:3923.9886029763375
#
# npas: 60; hout: 2500; p: 0.05
# 2/2 [==============================] - 1s 128ms/step
# MAE without education:132460.00681159346
# 2/2 [==============================] - 1s 138ms/step
# MAE with education:3886.690670358969
#
# npas: 72; hout: 2500; p: 0.05
# 2/2 [==============================] - 2s 145ms/step
# MAE without education:136164.977430707
# 2/2 [==============================] - 1s 140ms/step
# MAE with education:9430.062415726166
#
# npas: 84; hout: 2500; p: 0.05
# 2/2 [==============================] - 2s 209ms/step
# MAE without education:146462.55451187486
# 2/2 [==============================] - 1s 163ms/step
# MAE with education:4933.843698649625
#
# npas: 96; hout: 2500; p: 0.05
# 2/2 [==============================] - 1s 214ms/step
# MAE without education:154224.66639990592
# 2/2 [==============================] - 1s 320ms/step
# MAE with education:4677.943782941043
#
# npas: 108; hout: 2500; p: 0.05
# 2/2 [==============================] - 1s 244ms/step
# MAE without education:124720.16160460051
# 2/2 [==============================] - 1s 276ms/step
# MAE with education:12532.979993832518
#
# npas: 120; hout: 2500; p: 0.05
# 2/2 [==============================] - 2s 260ms/step
# MAE without education:140532.35260225864
# 2/2 [==============================] - 2s 630ms/step
# MAE with education:3413.167773809951

# %%
#grid_search = grid_search.fit(trainX,trainY)
for key in best_params.keys():
    print(key, ': ', best_params[key], sep="")
# Out:
# npas: 12
# hout: 1000
# p: 0.05

# %%
fig, axes = plt.subplots(nrows=7, ncols=2, dpi=150, figsize=(10,10))
for i, (col,ax) in enumerate(zip(df.columns, axes.flatten())):
    pd.Series(data=best[:, i], name="pred").plot(legend=True, ax=ax).autoscale(axis='x',tight=True)
    pd.Series(data=best_test[:, i], name="test").plot(legend=True, ax=ax);
    ax.set_title(col + ": Forecast vs Actuals")
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)

plt.tight_layout();

# %% [markdown]
# Для моделей вероятность дропаута я возьму 0.05, размер внутреннего слоя - 1500 (потому что 1500 больше, чем 1000, а больше - лучше, однако 2500 я не буду брать, чтобы не училось слишком долго), npas возьму равный 72, потому что на нём также был неплохой лосс.

# %%
from sklearn.preprocessing import MinMaxScaler

npas = 72
hout = 2500
p=0.05
scaler = MinMaxScaler(feature_range=(0, 1))
train_scaled = scaler.fit_transform(train)
test_scaled = scaler.fit_transform(test)
trainX,trainY=createXY(train_scaled,npas)
testX,testY=createXY(np.concatenate((train_scaled[-npas:,:], test_scaled), axis=0),npas)

# %%
# %%time
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.optimizers import Nadam


def build_model_RNN(npas, hout, p):
    icol = 14
    grid_model = Sequential()
    grid_model.add(SimpleRNN(hout, input_shape=(npas,icol), activation='relu'))#, return_sequences=True))
    grid_model.add(Dropout(p))
    grid_model.add(Dense(icol + int((hout - icol) * 0.5)))
    grid_model.add(Dense(icol))

    grid_model.compile(loss = 'mse', optimizer = Nadam(learning_rate=1e-3))
    return grid_model

#grid_model = KerasRegressor(model=build_model(npas, hout, p),verbose=1, fit__validation_data=(testX,testY))
grid_model = build_model_RNN(npas, hout, p)
'''grid_search  = GridSearchCV(estimator = grid_model,
                                param_grid = {'epochs': [15]},
                                cv = 2,
                                verbose=True)'''
grid_fit = grid_model.fit(trainX,trainY,epochs=30,batch_size=64,verbose=1)
prediction=grid_model.predict(testX)
testY_reverse, prediction_reverse = scaler.inverse_transform(testY), scaler.inverse_transform(prediction)
fig, axes = plt.subplots(nrows=7, ncols=2, dpi=150, figsize=(10,10))
for i, (col,ax) in enumerate(zip(df.columns, axes.flatten())):
    pd.Series(data=prediction_reverse[:, i], name="pred").plot(legend=True, ax=ax).autoscale(axis='x',tight=True)
    pd.Series(data=testY_reverse[:, i], name="test").plot(legend=True, ax=ax);
    ax.set_title(col + ": Forecast vs Actuals")
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)

plt.tight_layout();
# Out:
# Epoch 1/30
# 18/18 [==============================] - 22s 1s/step - loss: 1.1205
# Epoch 2/30
# 18/18 [==============================] - 19s 1s/step - loss: 0.0019
# Epoch 3/30
# 18/18 [==============================] - 19s 1s/step - loss: 9.3879e-04
# Epoch 4/30
# 18/18 [==============================] - 19s 1s/step - loss: 6.3367e-04
# Epoch 5/30
# 18/18 [==============================] - 19s 1s/step - loss: 5.4246e-04
# Epoch 6/30
# 18/18 [==============================] - 19s 1s/step - loss: 5.7230e-04
# Epoch 7/30
# 18/18 [==============================] - 19s 1s/step - loss: 4.7864e-04
# Epoch 8/30
# 18/18 [==============================] - 19s 1s/step - loss: 4.3330e-04
# Epoch 9/30
# 18/18 [==============================] - 19s 1s/step - loss: 4.2929e-04
# Epoch 10/30
# 18/18 [==============================] - 20s 1s/step - loss: 4.4188e-04
# Epoch 11/30
# 18/18 [==============================] - 20s 1s/step - loss: 4.5629e-04
# Epoch 12/30
# 18/18 [==============================] - 20s 1s/step - loss: 3.6769e-04
# Epoch 13/30
# 18/18 [==============================] - 20s 1s/step - loss: 3.7923e-04
# Epoch 14/30
# 18/18 [==============================] - 19s 1s/step - loss: 3.6592e-04
# Epoch 15/30
# 18/18 [==============================] - 19s 1s/step - loss: 3.1890e-04
# Epoch 16/30
# 18/18 [==============================] - 19s 1s/step - loss: 3.6188e-04
# Epoch 17/30
# 18/18 [==============================] - 19s 1s/step - loss: 3.3323e-04
# Epoch 18/30
# 18/18 [==============================] - 19s 1s/step - loss: 3.1582e-04
# Epoch 19/30
# 18/18 [==============================] - 19s 1s/step - loss: 3.8946e-04
# Epoch 20/30
# 18/18 [==============================] - 19s 1s/step - loss: 2.9753e-04
# Epoch 21/30
# 18/18 [==============================] - 19s 1s/step - loss: 2.8333e-04
# Epoch 22/30
# 18/18 [==============================] - 20s 1s/step - loss: 3.6515e-04
# Epoch 23/30
# 18/18 [==============================] - 19s 1s/step - loss: 2.8769e-04
# Epoch 24/30
# 18/18 [==============================] - 19s 1s/step - loss: 3.7250e-04
# Epoch 25/30
# 18/18 [==============================] - 19s 1s/step - loss: 3.0310e-04
# Epoch 26/30
# 18/18 [==============================] - 19s 1s/step - loss: 3.3727e-04
# Epoch 27/30
# 18/18 [==============================] - 19s 1s/step - loss: 2.7557e-04
# Epoch 28/30
# 18/18 [==============================] - 19s 1s/step - loss: 2.9473e-04
# Epoch 29/30
# 18/18 [==============================] - 22s 1s/step - loss: 2.6008e-04
# Epoch 30/30
# 18/18 [==============================] - 19s 1s/step - loss: 2.4263e-04
# 5/5 [==============================] - 1s 123ms/step
# CPU times: total: 2h 3min 7s
# Wall time: 9min 47s

# %%
validate(testY_reverse, prediction_reverse)
# Out:
# MSE: 118143733.21798666
# RMSE: 10869.394335379808
# MAE: 2407.514934521782
# MAPE: 3.2505110415100673
# R2: 0.4959223914302638

# %% [markdown]
# Рекордно низкий MAPE - значит, очень небольшое расстояние между графиками. Да и графики предиктов по своей "форме", в отличие от классических моделей, очень похожи на реальные значения (разве что, кроме, indpro, у которого в предикте медленный рост, тогда как на самом деле - медленное убывание, а также gte, у которого заметно предикт заметно больше реальных значений). Тем не менее, R2 низкий.

# %% [markdown]
# UPD. Добавил эпох (10 -> 30), изменил оптимизатор (Adam -> Nadam) и увеличил размерность выхода реккурентного слоя (1500 -> 2500). R2 стал немного лучше, но всё ещё так себе.

# %%
# %%time
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.optimizers import Nadam

def build_model_LSTM(npas, hout, p):
    icol = 14
    grid_model = Sequential()
    grid_model.add(LSTM(hout, input_shape=(npas,icol), activation='relu'))
    grid_model.add(Dropout(p))
    grid_model.add(Dense(icol + int((hout - icol) * 0.5)))
    grid_model.add(Dense(icol))

    grid_model.compile(loss = 'mse', optimizer = Nadam(learning_rate=2e-4))
    return grid_model


#grid_model = KerasRegressor(model=build_model(npas, hout, p),verbose=1, fit__validation_data=(testX,testY))
grid_model = build_model_LSTM(npas, hout, p)
'''grid_search  = GridSearchCV(estimator = grid_model,
                                param_grid = {'epochs': [15]},
                                cv = 2,
                                verbose=True)'''
grid_fit = grid_model.fit(trainX,trainY,epochs=30,batch_size=64,verbose=1)
prediction=grid_model.predict(testX)
testY_reverse, prediction_reverse = scaler.inverse_transform(testY), scaler.inverse_transform(prediction)
fig, axes = plt.subplots(nrows=7, ncols=2, dpi=150, figsize=(10,10))
for i, (col,ax) in enumerate(zip(df.columns, axes.flatten())):
    pd.Series(data=prediction_reverse[:, i], name="pred").plot(legend=True, ax=ax).autoscale(axis='x',tight=True)
    pd.Series(data=testY_reverse[:, i], name="test").plot(legend=True, ax=ax);
    ax.set_title(col + ": Forecast vs Actuals")
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)

plt.tight_layout();
# Out:
# Epoch 1/30
# 18/18 [==============================] - 80s 4s/step - loss: 0.0688
# Epoch 2/30
# 18/18 [==============================] - 77s 4s/step - loss: 0.0034
# Epoch 3/30
# 18/18 [==============================] - 82s 5s/step - loss: 0.0013
# Epoch 4/30
# 18/18 [==============================] - 82s 5s/step - loss: 8.2112e-04
# Epoch 5/30
# 18/18 [==============================] - 82s 5s/step - loss: 5.8506e-04
# Epoch 6/30
# 18/18 [==============================] - 77s 4s/step - loss: 4.7889e-04
# Epoch 7/30
# 18/18 [==============================] - 77s 4s/step - loss: 3.9251e-04
# Epoch 8/30
# 18/18 [==============================] - 77s 4s/step - loss: 3.4169e-04
# Epoch 9/30
# 18/18 [==============================] - 81s 4s/step - loss: 3.0462e-04
# Epoch 10/30
# 18/18 [==============================] - 86s 5s/step - loss: 2.8202e-04
# Epoch 11/30
# 18/18 [==============================] - 90s 5s/step - loss: 3.0383e-04
# Epoch 12/30
# 18/18 [==============================] - 89s 5s/step - loss: 2.5730e-04
# Epoch 13/30
# 18/18 [==============================] - 89s 5s/step - loss: 2.4473e-04
# Epoch 14/30
# 18/18 [==============================] - 90s 5s/step - loss: 2.3251e-04
# Epoch 15/30
# 18/18 [==============================] - 89s 5s/step - loss: 2.2894e-04
# Epoch 16/30
# 18/18 [==============================] - 84s 5s/step - loss: 2.1892e-04
# Epoch 17/30
# 18/18 [==============================] - 87s 5s/step - loss: 2.1174e-04
# Epoch 18/30
# 18/18 [==============================] - 88s 5s/step - loss: 2.2989e-04
# Epoch 19/30
# 18/18 [==============================] - 89s 5s/step - loss: 1.9917e-04
# Epoch 20/30
# 18/18 [==============================] - 89s 5s/step - loss: 1.9787e-04
# Epoch 21/30
# 18/18 [==============================] - 89s 5s/step - loss: 1.9379e-04
# Epoch 22/30
# 18/18 [==============================] - 86s 5s/step - loss: 1.8338e-04
# Epoch 23/30
# 18/18 [==============================] - 87s 5s/step - loss: 1.9328e-04
# Epoch 24/30
# 18/18 [==============================] - 87s 5s/step - loss: 1.9229e-04
# Epoch 25/30
# 18/18 [==============================] - 87s 5s/step - loss: 1.8470e-04
# Epoch 26/30
# 18/18 [==============================] - 86s 5s/step - loss: 1.8287e-04
# Epoch 27/30
# 18/18 [==============================] - 85s 5s/step - loss: 1.6733e-04
# Epoch 28/30
# 18/18 [==============================] - 82s 5s/step - loss: 1.6679e-04
# Epoch 29/30
# 18/18 [==============================] - 86s 5s/step - loss: 1.6908e-04
# Epoch 30/30
# 18/18 [==============================] - 85s 5s/step - loss: 1.6288e-04
# 5/5 [==============================] - 4s 699ms/step
# CPU times: total: 8h 46min 27s
# Wall time: 42min 39s

# %%
validate(testY_reverse, prediction_reverse)
# Out:
# MSE: 151396365.73320007
# RMSE: 12304.323050586736
# MAE: 2534.745629638899
# MAPE: 3.5767024907148266
# R2: 0.34226390481302366

# %% [markdown]
# Ситуация как с предыдущей моделью: MAPE маленький, "формы" графиков друг на друга похожи, но R2 низкий.

# %% [markdown]
# UPD. Добавил эпох (10 -> 30), изменил оптимизатор (Adam -> Nadam) и увеличил размерность выхода реккурентного слоя (1500 -> 2500). R2 стал заметно лучше, но всё ещё довольно плохо.

# %%
from sklearn.preprocessing import MinMaxScaler

npas = 12
hout = 2500
p=0.05

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
train_scaled = scaler.fit_transform(train.drop(["gte"], axis="columns"))
test_scaled = scaler.fit_transform(test.drop(["gte"], axis="columns"))
trainX,trainY=createXY(train_scaled,npas)
#testX,testY=createXY(np.concatenate((train_scaled[-npas:,:], test_scaled), axis=0),npas)
testX,testY=createXY(test_scaled,npas)

# %%
# %%time
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.optimizers import Nadam, Adadelta


def build_model_GRU(npas, hout, p):
    icol = 13
    grid_model = Sequential()
    #grid_model.add(GRU(hout, input_shape=(npas,icol), return_sequences=True))
    grid_model.add(GRU(hout, input_shape=(npas,icol)))
    grid_model.add(Dropout(p))
    grid_model.add(Dense(icol + int((hout - icol) * 0.5), activation='relu'))
    grid_model.add(Dense(icol))

    grid_model.compile(loss = 'mse', optimizer = Nadam(learning_rate=1e-4))
    return grid_model

#grid_model = KerasRegressor(model=build_model(npas, hout, p),verbose=1, fit__validation_data=(testX,testY))
grid_model = build_model_GRU(npas, hout, p)
'''grid_search  = GridSearchCV(estimator = grid_model,
                                param_grid = {'epochs': [15]},
                                cv = 2,
                                verbose=True)'''
grid_fit = grid_model.fit(trainX,trainY,epochs=100,batch_size=32,verbose=1)
prediction=grid_model.predict(testX)
testY_reverse, prediction_reverse = scaler.inverse_transform(testY), scaler.inverse_transform(prediction)
# Out:
# Epoch 1/100
# 38/38 [==============================] - 27s 663ms/step - loss: 0.0432
# Epoch 2/100
# 38/38 [==============================] - 25s 648ms/step - loss: 0.0013
# Epoch 3/100
# 38/38 [==============================] - 25s 653ms/step - loss: 7.0850e-04
# Epoch 4/100
# 38/38 [==============================] - 25s 648ms/step - loss: 4.7748e-04
# Epoch 5/100
# 38/38 [==============================] - 25s 646ms/step - loss: 3.6435e-04
# Epoch 6/100
# 38/38 [==============================] - 25s 647ms/step - loss: 2.9916e-04
# Epoch 7/100
# 38/38 [==============================] - 25s 648ms/step - loss: 2.7121e-04
# Epoch 8/100
# 38/38 [==============================] - 25s 648ms/step - loss: 2.5408e-04
# Epoch 9/100
# 38/38 [==============================] - 25s 649ms/step - loss: 2.2992e-04
# Epoch 10/100
# 38/38 [==============================] - 25s 651ms/step - loss: 2.1147e-04
# Epoch 11/100
# 38/38 [==============================] - 25s 648ms/step - loss: 2.0377e-04
# Epoch 12/100
# 38/38 [==============================] - 25s 652ms/step - loss: 1.9219e-04
# Epoch 13/100
# 38/38 [==============================] - 25s 651ms/step - loss: 1.8221e-04
# Epoch 14/100
# 38/38 [==============================] - 25s 653ms/step - loss: 1.7495e-04
# Epoch 15/100
# 38/38 [==============================] - 25s 654ms/step - loss: 1.6302e-04
# Epoch 16/100
# 38/38 [==============================] - 25s 652ms/step - loss: 1.6470e-04
# Epoch 17/100
# 38/38 [==============================] - 25s 652ms/step - loss: 1.5510e-04
# Epoch 18/100
# 38/38 [==============================] - 25s 648ms/step - loss: 1.4748e-04
# Epoch 19/100
# 38/38 [==============================] - 25s 648ms/step - loss: 1.4794e-04
# Epoch 20/100
# 38/38 [==============================] - 25s 649ms/step - loss: 1.4298e-04
# Epoch 21/100
# 38/38 [==============================] - 25s 649ms/step - loss: 1.3354e-04
# Epoch 22/100
# 38/38 [==============================] - 25s 649ms/step - loss: 1.3328e-04
# Epoch 23/100
# 38/38 [==============================] - 25s 648ms/step - loss: 1.3160e-04
# Epoch 24/100
# 38/38 [==============================] - 25s 653ms/step - loss: 1.2508e-04
# Epoch 25/100
# 38/38 [==============================] - 25s 651ms/step - loss: 1.2044e-04
# Epoch 26/100
# 38/38 [==============================] - 25s 650ms/step - loss: 1.1855e-04
# Epoch 27/100
# 38/38 [==============================] - 25s 650ms/step - loss: 1.2013e-04
# Epoch 28/100
# 38/38 [==============================] - 25s 648ms/step - loss: 1.1326e-04
# Epoch 29/100
# 38/38 [==============================] - 25s 651ms/step - loss: 1.1460e-04
# Epoch 30/100
# 38/38 [==============================] - 25s 649ms/step - loss: 1.1200e-04
# Epoch 31/100
# 38/38 [==============================] - 25s 650ms/step - loss: 1.0751e-04
# Epoch 32/100
# 38/38 [==============================] - 25s 649ms/step - loss: 1.0754e-04
# Epoch 33/100
# 38/38 [==============================] - 25s 649ms/step - loss: 1.0493e-04
# Epoch 34/100
# 38/38 [==============================] - 25s 649ms/step - loss: 1.0523e-04
# Epoch 35/100
# 38/38 [==============================] - 25s 649ms/step - loss: 1.0225e-04
# Epoch 36/100
# 38/38 [==============================] - 25s 649ms/step - loss: 9.9294e-05
# Epoch 37/100
# 38/38 [==============================] - 25s 649ms/step - loss: 9.4682e-05
# Epoch 38/100
# 38/38 [==============================] - 25s 649ms/step - loss: 9.7178e-05
# Epoch 39/100
# 38/38 [==============================] - 25s 648ms/step - loss: 9.4709e-05
# Epoch 40/100
# 38/38 [==============================] - 25s 649ms/step - loss: 9.3399e-05
# Epoch 41/100
# 38/38 [==============================] - 25s 647ms/step - loss: 9.3776e-05
# Epoch 42/100
# 38/38 [==============================] - 25s 648ms/step - loss: 8.8388e-05
# Epoch 43/100
# 38/38 [==============================] - 25s 648ms/step - loss: 8.8904e-05
# Epoch 44/100
# 38/38 [==============================] - 25s 649ms/step - loss: 8.6072e-05
# Epoch 45/100
# 38/38 [==============================] - 25s 650ms/step - loss: 8.4035e-05
# Epoch 46/100
# 38/38 [==============================] - 25s 651ms/step - loss: 8.7773e-05
# Epoch 47/100
# 38/38 [==============================] - 25s 649ms/step - loss: 8.4775e-05
# Epoch 48/100
# 38/38 [==============================] - 25s 649ms/step - loss: 8.1663e-05
# Epoch 49/100
# 38/38 [==============================] - 25s 649ms/step - loss: 7.8239e-05
# Epoch 50/100
# 38/38 [==============================] - 25s 649ms/step - loss: 8.1350e-05
# Epoch 51/100
# 38/38 [==============================] - 25s 649ms/step - loss: 8.0708e-05
# Epoch 52/100
# 38/38 [==============================] - 25s 650ms/step - loss: 7.7719e-05
# Epoch 53/100
# 38/38 [==============================] - 25s 650ms/step - loss: 7.6903e-05
# Epoch 54/100
# 38/38 [==============================] - 25s 652ms/step - loss: 7.6355e-05
# Epoch 55/100
# 38/38 [==============================] - 25s 654ms/step - loss: 7.2614e-05
# Epoch 56/100
# 38/38 [==============================] - 25s 651ms/step - loss: 7.2825e-05
# Epoch 57/100
# 38/38 [==============================] - 25s 648ms/step - loss: 7.1256e-05
# Epoch 58/100
# 38/38 [==============================] - 25s 651ms/step - loss: 7.3410e-05
# Epoch 59/100
# 38/38 [==============================] - 25s 649ms/step - loss: 6.9553e-05
# Epoch 60/100
# 38/38 [==============================] - 25s 648ms/step - loss: 7.0445e-05
# Epoch 61/100
# 38/38 [==============================] - 25s 648ms/step - loss: 7.1704e-05
# Epoch 62/100
# 38/38 [==============================] - 25s 648ms/step - loss: 7.3576e-05
# Epoch 63/100
# 38/38 [==============================] - 25s 649ms/step - loss: 6.9069e-05
# Epoch 64/100
# 38/38 [==============================] - 25s 651ms/step - loss: 6.9676e-05
# Epoch 65/100
# 38/38 [==============================] - 25s 649ms/step - loss: 6.7304e-05
# Epoch 66/100
# 38/38 [==============================] - 25s 648ms/step - loss: 6.5479e-05
# Epoch 67/100
# 38/38 [==============================] - 25s 648ms/step - loss: 7.4818e-05
# Epoch 68/100
# 38/38 [==============================] - 25s 650ms/step - loss: 7.0733e-05
# Epoch 69/100
# 38/38 [==============================] - 25s 649ms/step - loss: 6.7446e-05
# Epoch 70/100
# 38/38 [==============================] - 25s 650ms/step - loss: 6.6535e-05
# Epoch 71/100
# 38/38 [==============================] - 25s 650ms/step - loss: 6.2514e-05
# Epoch 72/100
# 38/38 [==============================] - 25s 648ms/step - loss: 6.3124e-05
# Epoch 73/100
# 38/38 [==============================] - 25s 650ms/step - loss: 6.0088e-05
# Epoch 74/100
# 38/38 [==============================] - 25s 659ms/step - loss: 6.3664e-05
# Epoch 75/100
# 38/38 [==============================] - 27s 712ms/step - loss: 6.1381e-05
# Epoch 76/100
# 38/38 [==============================] - 27s 710ms/step - loss: 6.3741e-05
# Epoch 77/100
# 38/38 [==============================] - 27s 709ms/step - loss: 5.7785e-05
# Epoch 78/100
# 38/38 [==============================] - 27s 710ms/step - loss: 6.2968e-05
# Epoch 79/100
# 38/38 [==============================] - 27s 709ms/step - loss: 5.8960e-05
# Epoch 80/100
# 38/38 [==============================] - 27s 709ms/step - loss: 6.4867e-05
# Epoch 81/100
# 38/38 [==============================] - 27s 707ms/step - loss: 5.6259e-05
# Epoch 82/100
# 38/38 [==============================] - 27s 710ms/step - loss: 5.5519e-05
# Epoch 83/100
# 38/38 [==============================] - 27s 710ms/step - loss: 6.0994e-05
# Epoch 84/100
# 38/38 [==============================] - 26s 679ms/step - loss: 5.7125e-05
# Epoch 85/100
# 38/38 [==============================] - 24s 637ms/step - loss: 5.9997e-05
# Epoch 86/100
# 38/38 [==============================] - 24s 635ms/step - loss: 6.2126e-05
# Epoch 87/100
# 38/38 [==============================] - 24s 634ms/step - loss: 5.5391e-05
# Epoch 88/100
# 38/38 [==============================] - 24s 635ms/step - loss: 5.6132e-05
# Epoch 89/100
# 38/38 [==============================] - 24s 637ms/step - loss: 5.6894e-05
# Epoch 90/100
# 38/38 [==============================] - 24s 636ms/step - loss: 6.7204e-05
# Epoch 91/100
# 38/38 [==============================] - 24s 634ms/step - loss: 5.4288e-05
# Epoch 92/100
# 38/38 [==============================] - 24s 634ms/step - loss: 5.7984e-05
# Epoch 93/100
# 38/38 [==============================] - 24s 634ms/step - loss: 5.5877e-05
# Epoch 94/100
# 38/38 [==============================] - 24s 635ms/step - loss: 5.2404e-05
# Epoch 95/100
# 38/38 [==============================] - 24s 639ms/step - loss: 5.4873e-05
# Epoch 96/100
# 38/38 [==============================] - 24s 636ms/step - loss: 5.7598e-05
# Epoch 97/100
# 38/38 [==============================] - 24s 640ms/step - loss: 5.1409e-05
# Epoch 98/100
# 38/38 [==============================] - 24s 642ms/step - loss: 5.0963e-05
# Epoch 99/100
# 38/38 [==============================] - 24s 639ms/step - loss: 4.9061e-05
# Epoch 100/100
# 38/38 [==============================] - 24s 638ms/step - loss: 5.0983e-05
# 4/4 [==============================] - 1s 77ms/step
# CPU times: total: 9h 7min 31s
# Wall time: 41min 31s

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
train_scaled = scaler.fit_transform(train['gte'].to_numpy().reshape(-1, 1))
test_scaled = scaler.fit_transform(test['gte'].to_numpy().reshape(-1, 1))
trainX,trainY=createXY(train_scaled,npas)
#testX,testY=createXY(np.concatenate((train_scaled[-npas:,:], test_scaled), axis=0),npas)
testX,testY=createXY(test_scaled,npas)

# %%
# %%time
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.optimizers import Nadam, Adadelta


def build_model_GRU(npas, hout, p):
    icol = 1
    grid_model = Sequential()
    #grid_model.add(GRU(hout, input_shape=(npas,icol), return_sequences=True))
    grid_model.add(GRU(hout, input_shape=(npas,icol)))
    grid_model.add(Dropout(p))
    grid_model.add(Dense(icol + int((hout - icol) * 0.5), activation='relu'))
    grid_model.add(Dense(icol))

    grid_model.compile(loss = 'mse', optimizer = Nadam(learning_rate=1e-4))
    return grid_model

#grid_model = KerasRegressor(model=build_model(npas, hout, p),verbose=1, fit__validation_data=(testX,testY))
grid_model = build_model_GRU(npas, hout, p)
'''grid_search  = GridSearchCV(estimator = grid_model,
                                param_grid = {'epochs': [15]},
                                cv = 2,
                                verbose=True)'''
grid_fit = grid_model.fit(trainX,trainY,epochs=100,batch_size=32,verbose=1)
prediction=grid_model.predict(testX)
testY_reverse_gte, prediction_reverse_gte= scaler.inverse_transform(testY), scaler.inverse_transform(prediction)
# Out:
# Epoch 1/100
# 38/38 [==============================] - 27s 651ms/step - loss: 0.0364
# Epoch 2/100
# 38/38 [==============================] - 25s 652ms/step - loss: 2.9553e-05
# Epoch 3/100
# 38/38 [==============================] - 25s 650ms/step - loss: 2.6724e-05
# Epoch 4/100
# 38/38 [==============================] - 25s 649ms/step - loss: 2.8292e-05
# Epoch 5/100
# 38/38 [==============================] - 25s 649ms/step - loss: 3.0573e-05
# Epoch 6/100
# 38/38 [==============================] - 25s 650ms/step - loss: 2.5547e-05
# Epoch 7/100
# 38/38 [==============================] - 25s 650ms/step - loss: 2.6310e-05
# Epoch 8/100
# 38/38 [==============================] - 25s 650ms/step - loss: 2.6160e-05
# Epoch 9/100
# 38/38 [==============================] - 25s 650ms/step - loss: 2.8574e-05
# Epoch 10/100
# 38/38 [==============================] - 25s 647ms/step - loss: 3.2403e-05
# Epoch 11/100
# 38/38 [==============================] - 25s 650ms/step - loss: 3.1019e-05
# Epoch 12/100
# 38/38 [==============================] - 25s 649ms/step - loss: 3.7985e-05
# Epoch 13/100
# 38/38 [==============================] - 25s 650ms/step - loss: 2.3980e-05
# Epoch 14/100
# 38/38 [==============================] - 25s 651ms/step - loss: 3.1802e-05
# Epoch 15/100
# 38/38 [==============================] - 25s 650ms/step - loss: 3.9618e-05
# Epoch 16/100
# 38/38 [==============================] - 25s 649ms/step - loss: 2.9191e-05
# Epoch 17/100
# 38/38 [==============================] - 25s 649ms/step - loss: 2.2106e-05
# Epoch 18/100
# 38/38 [==============================] - 25s 650ms/step - loss: 3.7199e-05
# Epoch 19/100
# 38/38 [==============================] - 25s 647ms/step - loss: 3.8229e-05
# Epoch 20/100
# 38/38 [==============================] - 25s 655ms/step - loss: 2.8587e-05
# Epoch 21/100
# 38/38 [==============================] - 25s 650ms/step - loss: 2.4294e-05
# Epoch 22/100
# 38/38 [==============================] - 25s 650ms/step - loss: 2.4210e-05
# Epoch 23/100
# 38/38 [==============================] - 25s 650ms/step - loss: 3.2263e-05
# Epoch 24/100
# 38/38 [==============================] - 25s 648ms/step - loss: 4.6682e-05
# Epoch 25/100
# 38/38 [==============================] - 25s 649ms/step - loss: 3.0842e-05
# Epoch 26/100
# 38/38 [==============================] - 25s 653ms/step - loss: 2.0497e-05
# Epoch 27/100
# 38/38 [==============================] - 25s 649ms/step - loss: 7.3780e-05
# Epoch 28/100
# 38/38 [==============================] - 25s 651ms/step - loss: 3.1903e-05
# Epoch 29/100
# 38/38 [==============================] - 25s 649ms/step - loss: 3.3565e-05
# Epoch 30/100
# 38/38 [==============================] - 25s 649ms/step - loss: 2.5457e-05
# Epoch 31/100
# 38/38 [==============================] - 25s 649ms/step - loss: 2.7786e-05
# Epoch 32/100
# 38/38 [==============================] - 25s 652ms/step - loss: 3.1152e-05
# Epoch 33/100
# 38/38 [==============================] - 25s 650ms/step - loss: 3.1474e-05
# Epoch 34/100
# 38/38 [==============================] - 25s 648ms/step - loss: 2.9808e-05
# Epoch 35/100
# 38/38 [==============================] - 25s 652ms/step - loss: 2.8775e-05
# Epoch 36/100
# 38/38 [==============================] - 25s 655ms/step - loss: 2.3119e-05
# Epoch 37/100
# 38/38 [==============================] - 25s 655ms/step - loss: 4.4409e-05
# Epoch 38/100
# 38/38 [==============================] - 25s 651ms/step - loss: 2.7270e-05
# Epoch 39/100
# 38/38 [==============================] - 25s 651ms/step - loss: 2.3717e-05
# Epoch 40/100
# 38/38 [==============================] - 25s 651ms/step - loss: 7.5446e-05
# Epoch 41/100
# 38/38 [==============================] - 25s 650ms/step - loss: 4.2777e-05
# Epoch 42/100
# 38/38 [==============================] - 25s 649ms/step - loss: 2.6227e-05
# Epoch 43/100
# 38/38 [==============================] - 25s 647ms/step - loss: 2.6703e-05
# Epoch 44/100
# 38/38 [==============================] - 25s 652ms/step - loss: 2.1452e-05
# Epoch 45/100
# 38/38 [==============================] - 25s 651ms/step - loss: 3.3565e-05
# Epoch 46/100
# 38/38 [==============================] - 25s 660ms/step - loss: 3.5980e-05
# Epoch 47/100
# 38/38 [==============================] - 24s 639ms/step - loss: 2.9880e-05
# Epoch 48/100
# 38/38 [==============================] - 24s 638ms/step - loss: 5.7556e-05
# Epoch 49/100
# 38/38 [==============================] - 24s 638ms/step - loss: 2.0629e-05
# Epoch 50/100
# 38/38 [==============================] - 24s 640ms/step - loss: 2.2450e-05
# Epoch 51/100
# 38/38 [==============================] - 24s 638ms/step - loss: 6.0655e-05
# Epoch 52/100
# 38/38 [==============================] - 24s 639ms/step - loss: 2.0685e-05
# Epoch 53/100
# 38/38 [==============================] - 24s 638ms/step - loss: 2.9787e-05
# Epoch 54/100
# 38/38 [==============================] - 24s 640ms/step - loss: 4.3783e-05
# Epoch 55/100
# 38/38 [==============================] - 24s 637ms/step - loss: 2.0728e-05
# Epoch 56/100
# 38/38 [==============================] - 24s 638ms/step - loss: 2.6856e-05
# Epoch 57/100
# 38/38 [==============================] - 24s 636ms/step - loss: 2.6266e-05
# Epoch 58/100
# 38/38 [==============================] - 24s 638ms/step - loss: 2.7322e-05
# Epoch 59/100
# 38/38 [==============================] - 24s 637ms/step - loss: 2.3779e-05
# Epoch 60/100
# 38/38 [==============================] - 24s 639ms/step - loss: 3.6189e-05
# Epoch 61/100
# 38/38 [==============================] - 24s 640ms/step - loss: 2.0281e-05
# Epoch 62/100
# 38/38 [==============================] - 24s 637ms/step - loss: 4.2101e-05
# Epoch 63/100
# 38/38 [==============================] - 24s 637ms/step - loss: 2.8991e-05
# Epoch 64/100
# 38/38 [==============================] - 24s 639ms/step - loss: 3.3996e-05
# Epoch 65/100
# 38/38 [==============================] - 24s 638ms/step - loss: 3.4485e-05
# Epoch 66/100
# 38/38 [==============================] - 24s 636ms/step - loss: 4.5677e-05
# Epoch 67/100
# 38/38 [==============================] - 24s 638ms/step - loss: 4.2691e-05
# Epoch 68/100
# 38/38 [==============================] - 24s 637ms/step - loss: 2.9796e-05
# Epoch 69/100
# 38/38 [==============================] - 24s 639ms/step - loss: 2.8653e-05
# Epoch 70/100
# 38/38 [==============================] - 24s 636ms/step - loss: 1.8203e-05
# Epoch 71/100
# 38/38 [==============================] - 24s 638ms/step - loss: 2.5446e-05
# Epoch 72/100
# 38/38 [==============================] - 24s 638ms/step - loss: 2.0266e-05
# Epoch 73/100
# 38/38 [==============================] - 24s 640ms/step - loss: 4.2612e-05
# Epoch 74/100
# 38/38 [==============================] - 24s 638ms/step - loss: 7.2880e-05
# Epoch 75/100
# 38/38 [==============================] - 24s 643ms/step - loss: 2.8500e-05
# Epoch 76/100
# 38/38 [==============================] - 24s 642ms/step - loss: 3.2782e-05
# Epoch 77/100
# 38/38 [==============================] - 24s 640ms/step - loss: 2.3673e-05
# Epoch 78/100
# 38/38 [==============================] - 24s 638ms/step - loss: 2.8256e-05
# Epoch 79/100
# 38/38 [==============================] - 24s 638ms/step - loss: 2.8276e-05
# Epoch 80/100
# 38/38 [==============================] - 24s 639ms/step - loss: 1.8745e-05
# Epoch 81/100
# 38/38 [==============================] - 24s 636ms/step - loss: 3.0578e-05
# Epoch 82/100
# 38/38 [==============================] - 24s 639ms/step - loss: 3.4796e-05
# Epoch 83/100
# 38/38 [==============================] - 24s 638ms/step - loss: 1.7750e-05
# Epoch 84/100
# 38/38 [==============================] - 24s 641ms/step - loss: 4.9085e-05
# Epoch 85/100
# 38/38 [==============================] - 24s 638ms/step - loss: 3.1128e-05
# Epoch 86/100
# 38/38 [==============================] - 24s 638ms/step - loss: 3.1881e-05
# Epoch 87/100
# 38/38 [==============================] - 24s 638ms/step - loss: 2.9051e-05
# Epoch 88/100
# 38/38 [==============================] - 24s 639ms/step - loss: 2.4549e-05
# Epoch 89/100
# 38/38 [==============================] - 24s 638ms/step - loss: 2.4907e-05
# Epoch 90/100
# 38/38 [==============================] - 24s 638ms/step - loss: 2.4909e-05
# Epoch 91/100
# 38/38 [==============================] - 25s 647ms/step - loss: 2.0844e-05
# Epoch 92/100
# 38/38 [==============================] - 24s 640ms/step - loss: 2.2500e-05
# Epoch 93/100
# 38/38 [==============================] - 24s 639ms/step - loss: 1.9226e-05
# Epoch 94/100
# 38/38 [==============================] - 24s 638ms/step - loss: 3.7049e-05
# Epoch 95/100
# 38/38 [==============================] - 24s 639ms/step - loss: 2.2366e-05
# Epoch 96/100
# 38/38 [==============================] - 24s 638ms/step - loss: 1.1053e-04
# Epoch 97/100
# 38/38 [==============================] - 24s 638ms/step - loss: 1.8337e-05
# Epoch 98/100
# 38/38 [==============================] - 24s 640ms/step - loss: 2.3205e-05
# Epoch 99/100
# 38/38 [==============================] - 24s 638ms/step - loss: 1.6425e-05
# Epoch 100/100
# 38/38 [==============================] - 24s 637ms/step - loss: 1.9345e-05
# 4/4 [==============================] - 1s 77ms/step
# CPU times: total: 9h 1min 2s
# Wall time: 40min 55s

# %%
testY_reverse = np.insert(testY_reverse, [-1], testY_reverse_gte, axis=1)
prediction_reverse = np.insert(prediction_reverse, [-1], prediction_reverse_gte, axis=1)
fig, axes = plt.subplots(nrows=7, ncols=2, dpi=150, figsize=(10,10))
for i, (col,ax) in enumerate(zip(df.columns, axes.flatten())):
    pd.Series(data=prediction_reverse[:, i], name="pred").plot(legend=True, ax=ax).autoscale(axis='x',tight=True)
    pd.Series(data=testY_reverse[:, i], name="test").plot(legend=True, ax=ax);
    ax.set_title(col + ": Forecast vs Actuals")
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)

plt.tight_layout();

# %%
validate(testY_reverse, prediction_reverse)
# Out:
# MSE: 8694520.181943651
# RMSE: 2948.6471782740728
# MAE: 738.8953663391603
# MAPE: 1.0873766911251532
# R2: 0.904202558358235

# %%
for i in range(len(df.columns)):
    print(df.columns[i] + ":", r2_score(testY_reverse[:, i], prediction_reverse[:, i]))
# Out:
# unrate: 0.9530636980522038
# psr: 0.925041173626558
# m2: 0.9423878169086288
# dspic: 0.7696808189898945
# pce: 0.815101664505645
# reer: 0.9690629671767169
# ir: 0.9758633118396716
# ffer: 0.9554544882468766
# tcs: 0.954668570303136
# indpro: 0.8059704875249912
# ccpi: 0.9432937726749472
# gdp: 0.7281388264110653
# gte: 0.9637897224404013
# netexp: 0.9573184983145552

# %% [markdown]
# Несколько лучше, чем LSTM; в остальном - всё то же самое.

# %% [markdown]
# UPD. Добавил эпох (10 -> 30), изменил оптимизатор (Adam -> Nadam) и увеличил размерность выхода реккурентного слоя (1500 -> 2500). R2 стал заметно лучше, и теперь он довольно неплохой.

# %% [markdown]
# UPD 2. На GTE был очень низкий r2 (<-0.5), поэтому я решил позволить себе наглость сделать 2 нейросети, одна из которых предсказывает GTE, а вторая - всё остальное. В теории, в таком способе нет ничего зазорного, тем более, что это сработало, и мне удалось добиться r2 > 0.9.

# %% [markdown]
# Заключение: хоть R2 на нейронных сетях и оказались невысоки, имеющиеся результаты уже довольно неплохи, демонстрируя гораздо меньший MAPE, чем на классических моделях. Модели пришлось остановить на 10 эпохах, чтобы обучение не шло несколько часов, однако во всех трёх случаях обучение останавливалось до того, как лосс прекращал уменьшаться, так что можно предположить, что при большем количестве эпох можно было бы увидеть отличный результат на всех метриках. Кроме того, для нейронных сетей не важна стационарность ряда, так что в копилке плюсов нейронных сетей пополнение. Так что между нейронными сетями и классическими моделями я выбрал бы первое.

# %% [markdown]
# UPD. Изменив оптимизатор, а также увеличив число эпох и увеличив размерность выхода реккурентного слоя, мне удалось добиться приличного r2 на GRU.

# %% [markdown]
# UPD 2. С учётом r2 > 0.9 на GRU, нейронные сети оказываются не только более простыми в использовании, но также и практически сравнимыми по эффективности.
